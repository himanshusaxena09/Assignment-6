# %%
# What is TensorFlow 2.0, and how is it different from TensorFlow 1.x

# TensorFlow 2.0
# developed by Google Brain that provides tools to build, train, and deploy deep learning models.
# Neural networks (CNNs, RNNs, Transformers
# Natural language processing (NLP)
# Computer vision
# Reinforcement Learning
# And even production-level deployment using TensorFlow Serving or TensorFlow Lite

# TensorFlow 1.x
# Deep Learning Model Development
# Static Computational Graphs
# Model Training and Optimization
# Distributed Computing
# Serving and Deployment
# Research Prototyping

# %%
#  How do you install TensorFlow 2.0

# Prerequisites
# You have Python 3.7–3.11 installed -- python --version
# Create a Virtual Environment -- python -m venv tf_env
# Install TensorFlow 2.0 --  pip install tensorflow==2.0.0

# %%
#  What is the primary function of the tf.function in TensorFlow 2.0

# tf.function is used to Convert Python functions into TensorFlow graphs
# (graphs = faster execution)
# tf.function converts your Python code into a fast, optimized TensorFlow graph.
# It improves performance, portability, and scalability for training and inference.

# %%
#  What is the purpose of the Model class in TensorFlow 2.0

# In TensorFlow 2.0, the Model class represents a complete neural network
# Holds the layers of your network
# Defines the forward pass (computation)
# And provides built-in methods for training, evaluation, and prediction.

# %%
#  How do you create a neural network using TensorFlow 2.0

# Step 1: Import TensorFlow
# Step 2: Prepare Your Data
# Step 3: Build the Neural Network Model
# Step 4: Compile the Model
# Step 5: Train the Model
# Step 6: Evaluate the Model
# Step 7: Make Predictions
# Step 8: Save and Load the Model

# %%
#  What is the importance of Tensor Space in TensorFlow

# Tensor Space is the abstract space where all data (tensors) and computations (operations) live inside TensorFlow
# - Supports Multi-Dimensional Data
# - Enables Vectorized Operations
# - Defines Relationships Between Layers
# - Backpropagation & Gradients
# - Hardware Abstraction

# %%
# How can TensorBoard be integrated with TensorFlow 2.0

# Step 1  Import Libraries
# Step 2 Load and Prepare Data
# Step 3 Define the Model
# Step 4 Compile the Model
# Step 5 Create a TensorBoard Callback
# Step 6 Train the Model with TensorBoard
# Launch TensorBoard

# %%
# What is the purpose of TensorFlow Playground

# How neural networks work internally
# How different hyperparameters affect learning
# How layers and neurons transform input data
# How activation functions, learning rates, and regularization influence model performance

# %%
# What is Netron, and how is it useful for deep learning models

# Netron is a visualization tool for inspecting and understanding deep learning, neural network, and machine learning models
# It’s an open-source model viewer that allows you to see your model’s architecture, layers, parameters, and connections


# Visualize Architecture
# Understand Layer Details
# Debug Model Issues
# Cross-Framework Viewing
# Model Conversion Validation
# Education & Presentation

# %%
# What is the difference between TensorFlow and PyTorch

# TensorFlow -
# Programming Style Graph-based
# Large ecosystem; great for industry deployment
# TensorBoard for metrics, graphs
# Optimized for GPUs, TPUs, and large-scale distributed training
# Excellent for production

# PyTorch -
# Less mature for production; TorchServe available
# Popular in academia and research; fast prototyping
# Visdom, TensorBoard (optional), or Matplotlib
# Optimized for GPUs; distributed training improving

# %%
# How do you install PyTorch

# PyTorch is an open-source deep learning framework

# Install via pip
# Install via conda
# pip install torch

# %%
# What is the basic structure of a PyTorch neural network

# In PyTorch, a neural network is typically built using the torch.nn module

# Import Libraries
# Define the Neural Network Class
# Create Model Instance
# Define Loss Function & Optimizer
# Training Loop

# %%
#  What is the significance of tensors in PyTorch

# Core Data Type -- Represents all data (inputs, outputs, parameters)
# GPU Support -- Enables fast computations
# Autograd --	Supports automatic differentiation
# Mathematical Ops --	Simplifies model implementation
# Dynamic Graphs -- Makes debugging & experimentation easy
# Interoperable -- Works well with NumPy and Python ecosystem

# %%
#  What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch

# torch.Tensor — CPU Tensor

# Default tensor type.
# Stored in system memory (RAM).
# Operations are performed using the CPU.
# Slower for large-scale deep learning compared to GPU.

# torch.cuda.Tensor — GPU Tensor

# A tensor that lives on the GPU’s VRAM.
# Computations are performed using the CUDA cores on NVIDIA GPUs.
# Much faster for deep learning tasks.

# %%
#  What is the purpose of the torch.optim module in PyTorch

# The main purpose of torch.optim is to automate and manage the parameter updates based on the gradients computed during backpropagation.
# torch.optim automates parameter updates using gradients.
# It supports many built-in optimization algorithms.
# It integrates seamlessly with the autograd engine.
# It’s essential for training neural networks efficiently.

# %%
# What are some common activation functions used in neural networks

# Sigmoid (Logistic) Function
# Tanh (Hyperbolic Tangent)
# ReLU (Rectified Linear Unit)
# Leaky ReLU
# Softmax

# %%
# What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch

# torch.nn.Module :--

# nn.Module is the base class for all neural network components in PyTorch — layers, models, and even custom networks.
# You use it when you want full control over

# Model architecture
# Forward pass logic
# Complex layer connections

# torch.nn.Sequential :--

# nn.Sequential is a convenient container to create a model layer-by-layer in order, without writing a custom forward() method.

# Easier and shorter to define simple models
# Limited flexibility — cannot include complex operations or branching

# %%
# How can you monitor training progress in TensorFlow 2.0

# When you call model.fit(), TensorFlow automatically prints the training progress

# history = model.fit(
#     X_train, y_train,
#     epochs=10,
#     batch_size=32,
#     validation_data=(X_val, y_val),
#     verbose=1   # 1 = progress bar, 2 = one line per epoch
# )

# %%
# How does the Keras API fit into TensorFlow 2.0

# import tensorflow as tf
# from tensorflow.keras import layers, models

# Define a Sequential model
# model = models.Sequential([layers.Dense(128, activation='relu', input_shape=(784,)),
#     layers.Dropout(0.2),
#     layers.Dense(10, activation='softmax')])

# Compile the model
# model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# Train the model
# model.fit(X_train, y_train, epochs=5, validation_data=(X_val, y_val))

# %%
#  What is an example of a deep learning project that can be implemented using TensorFlow 2.0

# Handwritten Digit Recognition using the MNIST Dataset

# This is one of the most classic and beginner-friendly deep learning projects —
# you train a Convolutional Neural Network (CNN) to recognize digits (0–9) from handwritten images

# 1. Problem Overview
# 2. Import Libraries
# 3. Load and Prepare the Data
# 4. Build the CNN Model
# 5. Compile the Model
# 6. Train the Model
# 7. Evaluate Model Performance
# 8. Visualize Training Results
# 9. Make Predictions

# %%
#  What is the main advantage of using pre-trained models in TensorFlow and PyTorch

# The main advantage of using pre-trained models in TensorFlow and PyTorch is Transfer Learning
# you can leverage learned features from large, general-purpose datasets to speed up training, improve performance, and reduce data requirements for your specific task.

# Saves time -- Skip training from scratch
# Less data needed -- Works well with smaller datasets
# Higher accuracy --	Uses pre-learned general features
# Knowledge reuse --	Builds on large datasets like ImageNet
# Easy to fine-tune --	Just modify last few layers
# Available in frameworks --	torchvision.models, tf.keras.applications

# %%
# How do you install and verify that TensorFlow 2.0 was installed successfully

# import tensorflow as tf
# print(tf.__version__)

# %%
#  How can you define a simple function in TensorFlow 2.0 to perform addition

import tensorflow as tf

@tf.function
def add_numbers(a, b):
    return a + b

# Test the function
x = tf.constant(5)
y = tf.constant(7)
result = add_numbers(x, y)

tf.print("Result:", result)
# Out:
# Result: 12

# %%
#  How can you create a simple neural network in TensorFlow 2.0 with one hidden layer

import tensorflow as tf
from tensorflow.keras import layers, models

model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10,)),
    layers.Dense(1)
])

model.compile(optimizer='adam',loss='mse',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 16)             │           176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#  How can you visualize the training progress using TensorFlow and Matplotlib

import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# Simple model
model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape=(10,)),
    layers.Dense(1)
])

model.compile(optimizer='adam',
              loss='mse')

# Dummy dataset
X = np.random.rand(200, 10)
y = np.random.rand(200, 1)

history = model.fit(X, y, epochs=20, batch_size=8, verbose=1)

plt.plot(history.history['loss'])
plt.title('Training Loss Progress')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2397
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1524
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1207
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1243
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1128
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1077
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1017
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1106
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0869
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0934
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0903
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0845
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0984
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0819
# Epoch 15/20
# ...

# %%
#  How do you install PyTorch and verify the PyTorch installation

import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: False

# %%
#  How do you create a simple neural network in PyTorch

import torch
import torch.nn as nn
import torch.optim as optim

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.hidden = nn.Linear(10, 16)
        self.output = nn.Linear(16, 1)

    def forward(self, x):
        x = torch.relu(self.hidden(x))
        x = self.output(x)
        return x

model = SimpleNN()
print(model)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
# Out:
# SimpleNN(
#   (hidden): Linear(in_features=10, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
#  How do you define a loss function and optimizer in PyTorch

import torch.nn as nn

criterion = nn.MSELoss()
criterion = nn.CrossEntropyLoss()

import torch.optim as optim

optimizer = optim.Adam(model.parameters(), lr=0.001)
optim.SGD(model.parameters(), lr=0.01)
optim.RMSprop(model.parameters(), lr=0.001)
# Out:
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     capturable: False
#     centered: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     lr: 0.001
#     maximize: False
#     momentum: 0
#     weight_decay: 0
# )

# %%
#  How do you implement a custom loss function in PyTorch

# import torch

# def custom_loss(pred, target):
#     return torch.mean(torch.abs(pred - target))

# loss = custom_loss(outputs, y)

# %%
# How do you save and load a TensorFlow model

# Save a TensorFlow Model
# model.save("my_model")

# Load a TensorFlow Model
# loaded_model = tf.keras.models.load_model("my_model")

# loaded_model.summary()
